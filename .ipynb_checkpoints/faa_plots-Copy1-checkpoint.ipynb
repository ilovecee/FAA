# %%
# import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
#from jupyterthemes import jtplot
#jtplot.style(theme='gruvboxl')
#plt.style.use('ggplot')

# %%
# read data
df = pd.read_excel('faa_data_model.xlsx', sheet_name = 'clean_data', index_col = 'Combination')

# %%
df.columns
# Out:
# Index(['CIP', 'WBS', 'Fund Type', 'Task Description', 'Fiscal Year',
#        'The Year', 'Actual Expended Sum', 'Expended Sum Higher Spend Scenario',
#        'Expended Sum Lower Spend Scenario', 'Expended Sum Normal Distribution',
#        'Expended Sum Normal Distribution Higher Spend Scenario',
#        'Expended Sum Normal Distribution Lower Spend Scenario',
#        'Expended Sum Triangular Distribution',
#        'Expended Sum Triangular Distribution Higher Spend Scenario',
#        'Expended Sum Triangular Distribution Lower Spend Scenario',
#        'Expended Sum PERT Distribution',
#        'Expended Sum PERT Distribution Higher Spend Scenario',
#        'Expended Sum PERT Distribution Lower Spend Scenario',
#        'Expended Sum Uniform Distribution',
#        'Expended Sum Uniform Distribution Higher Spend Scenario',
#        'Expended Sum Uniform Distribution Lower Spend Scenario',
#        'Expended Sum LogNormal Distribution',
#        'Expended Sum LogNormal Distribution Higher Spend Scenario',
#        'Expended Sum LogNormal Distribution Lower Spend Scenario',
#        'Expended Sum Beta Distribution',
#        'Expended Sum Beta Distribution Higher Spend Scenario',
#        'Expended Sum Beta Distribution Lower Spend Scenario',
#        'Expended Sum Weibull Distribution',
#        'Expended Sum Weibull Distribution Higher Spend Scenario',
#        'Expended Sum Weibull Distribution Lower Spend Scenario',
#        'Commitment SUM', 'Obligation SUM', 'Total Obligations SUM'],
#       dtype='object')

# %%
x = df['Actual Expended Sum']
y = df['Obligation SUM']

plt.scatter(x, y)
plt.show()

# %%
df.groupby('WBS').mean()[['Actual Expended Sum', 'Expended Sum Higher Spend Scenario']]
# Out:
#         Actual Expended Sum  Expended Sum Higher Spend Scenario
# WBS
# WB1010         3.130308e+05                        3.443338e+05
# WB1020         1.058971e+06                        1.164868e+06
# WB1030         1.693695e+05                        1.863064e+05
# WB1040         9.602235e+05                        1.056246e+06
# WB1050         4.187048e+05                        4.605752e+05
# WB2010         8.272606e+05                        9.099866e+05
# WB2020         1.466743e+06                        1.613417e+06
# WB2030         3.836491e+04                        4.220140e+04
# WB3010         1.507958e+06                        1.658753e+06
# WB3020         2.967946e+06                        3.264741e+06
# WB3030         2.480010e+06                        2.728011e+06
# WB3040         4.582338e+05                        5.040572e+05
# WB3050         4.234719e+05                        4.658191e+05
# WB3060         1.273234e+05                        1.400558e+05
# WB3070         3.829254e+05                        4.212179e+05
# WB4010         2.207528e+06                        2.428281e+06
# WB4020         1.095173e+06                        1.204690e+06
# WB4030         1.099762e+06                        1.209738e+06
# WB4040         3.727615e+05                        4.100377e+05
# WB4050         1.605553e+06                        1.766108e+06
# WB4060         7.922069e+05                        8.714275e+05
# WB4070         2.946488e+04                        3.241137e+04
# WB4080         1.391886e+06                        1.531074e+06
# WB4090         1.204184e+05                        1.324603e+05
# WB5000         4.004468e+06                        4.404914e+06
# WB5010         2.067797e+05                        2.274577e+05
# WB5020         1.574424e+05                        1.731866e+05
# WB5030         1.270853e+05                        1.397938e+05
# WB5040         1.471587e+05                        1.618746e+05
# WB5050         0.000000e+00                        0.000000e+00
# WB5070         2.737878e+06                        3.011666e+06
# WB5080         1.184585e+05                        1.303043e+05
# WB5090         2.153476e+04                        2.368823e+04
# WB5100         5.002215e+06                        5.502437e+06
# WB5110         2.156506e+06                        2.372156e+06
# WB5120         5.278033e+05                        5.805836e+05
# WB5130         0.000000e+00                        0.000000e+00
# WB5140         0.000000e+00                        0.000000e+00
# WB5150         2.519616e+04                        2.771578e+04
# WB6010         2.807381e+04                        3.088119e+04
# WB6020         5.125637e+05                        5.638200e+05
# WB6030         2.754453e+04                        3.029899e+04
# WB6040         3.141163e+05                        3.455280e+05
# WB6050         6.053210e+04                        6.658531e+04
# WB6060         1.969814e+04                        2.166795e+04

# %%
# select columns with only 'Expended Sum' for plotting
exp_cols = list(filter(lambda x: 'Expended' in x, list(df.columns)))

# %%
exp_cols
# Out:
# ['Actual Expended Sum',
#  'Expended Sum Higher Spend Scenario',
#  'Expended Sum Lower Spend Scenario',
#  'Expended Sum Normal Distribution',
#  'Expended Sum Normal Distribution Higher Spend Scenario',
#  'Expended Sum Normal Distribution Lower Spend Scenario',
#  'Expended Sum Triangular Distribution',
#  'Expended Sum Triangular Distribution Higher Spend Scenario',
#  'Expended Sum Triangular Distribution Lower Spend Scenario',
#  'Expended Sum PERT Distribution',
#  'Expended Sum PERT Distribution Higher Spend Scenario',
#  'Expended Sum PERT Distribution Lower Spend Scenario',
#  'Expended Sum Uniform Distribution',
#  'Expended Sum Uniform Distribution Higher Spend Scenario',
#  'Expended Sum Uniform Distribution Lower Spend Scenario',
#  'Expended Sum LogNormal Distribution',
#  'Expended Sum LogNormal Distribution Higher Spend Scenario',
#  'Expended Sum LogNormal Distribution Lower Spend Scenario',
#  'Expended Sum Beta Distribution',
#  'Expended Sum Beta Distribution Higher Spend Scenario',
#  'Expended Sum Beta Distribution Lower Spend Scenario',
#  'Expended Sum Weibull Distribution',
#  'Expended Sum Weibull Distribution Higher Spend Scenario',
#  'Expended Sum Weibull Distribution Lower Spend Scenario']

# %%
# Plot the distributions

def plot_dist(n):
    n = n - 1
    plt.hist(df[exp_cols[n]], alpha = 0.5, label='Medium', cumulative=False)
    plt.hist(df[exp_cols[n + 1]], alpha = 0.5, label='High', cumulative=False)
    plt.hist(df[exp_cols[n + 2]], alpha = 0.5, label='Low', cumulative=False)
    plt.legend(loc='upper right')
    plt.title (exp_cols[n])
    plt.show()

plot_dist(4)

# %%
print (df['Expended Sum Normal Distribution'].std())
print (df['Expended Sum Normal Distribution Higher Spend Scenario'].std())
print (df['Expended Sum Normal Distribution Lower Spend Scenario'].std())
# Out:
# 4152111.457737049
# 4518670.447446785
# 3643153.255716437

# %%
a = 'abc'
b = 'def'

# %%
print('Hello World')
# Out:
# Hello World
